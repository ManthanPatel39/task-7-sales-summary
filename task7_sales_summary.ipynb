# %% [markdown]
# # Task 7 – Basic Sales Summary with Python & SQLite
# ## By Manthan Patel

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("sales_data.db")

# %%
query = """
SELECT product, 
       SUM(quantity) AS total_qty, 
       SUM(quantity * price) AS revenue 
FROM sales 
GROUP BY product
"""

# %%
df = pd.read_csv(r"C:\Users\Asus\Downloads\Online Sales Data.csv")

# %%
df_sales.to_sql("sales", conn, if_exists="replace", index=False)
# Out:
# 240

# %%
df = pd.read_sql_query(query, conn)

# %%
df_sales = df[['Product Name', 'Units Sold', 'Unit Price']].copy()
df_sales.columns = ['product', 'quantity', 'price']

# %%
print("Sales Summary:")
print(df)
# Out:
# Sales Summary:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
top_df = df.sort_values(by='revenue', ascending=False).head(10)
top_df.plot(kind='bar', x='product', y='revenue', title='Top 10 Products by Revenue', legend=False)
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig(r"C:\Users\Asus\OneDrive\Desktop\internship tasks\sales_chart.png")
plt.show()

# %%
import os
# Print the current working directory where the notebook is located
print(f"Current directory: {os.getcwd()}")
# Out:
# Current directory: C:\Users\Asus

# %%
conn.close()
